# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git init
# !git clone https://github.com/cswry/OSEDiff.git
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /kaggle/working/.git/
# Cloning into 'OSEDiff'...
# remote: Enumerating objects: 837, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 837 (delta 67), reused 204 (delta 61), pack-reused 625 (from 1)
# Receiving objects: 100% (837/837), 186.93 MiB | 19.57 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
# !pip install -r /kaggle/working/OSEDiff/requirements.txt
# Out:
# Collecting diffusers==0.25.0 (from -r /kaggle/working/OSEDiff/requirements.txt (line 1))
#   Downloading diffusers-0.25.0-py3-none-any.whl.metadata (19 kB)
# Collecting torch==2.0.1 (from -r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting transformers==4.28.1 (from -r /kaggle/working/OSEDiff/requirements.txt (line 3))
#   Downloading transformers-4.28.1-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.0/110.0 kB 7.6 MB/s eta 0:00:00
# Collecting xformers==0.0.20 (from -r /kaggle/working/OSEDiff/requirements.txt (line 4))
#   Downloading xformers-0.0.20-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting einops==0.7.0 (from -r /kaggle/working/OSEDiff/requirements.txt (line 5))
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting open-clip-torch==2.20.0 (from -r /kaggle/working/OSEDiff/requirements.txt (line 6))
#   Downloading open_clip_torch-2.20.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.6 MB/s eta 0:00:00
# Collecting peft==0.9.0 (from -r /kaggle/working/OSEDiff/requirements.txt (line 7))
#   Downloading peft-0.9.0-py3-none-any.whl.metadata (13 kB)
# Collecting Pillow==9.5.0 (from -r /kaggle/working/OSEDiff/requirements.txt (line 8))
#   Downloading Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting PyYAML==6.0 (from -r /kaggle/working/OSEDiff/requirements.txt (line 9))
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.0 kB)
# Collecting pyiqa==0.1.10 (from -r /kaggle/working/OSEDiff/requirements.txt (line 10))
#   Downloading pyiqa-0.1.10-py3-none-any.whl.metadata (14 kB)
# Collecting basicsr (from -r /kaggle/working/OSEDiff/requirements.txt (line 11))
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 13.4 MB/s eta 0:00:00
# done
# Collecting loralib (from -r /kaggle/working/OSEDiff/requirements.txt (line 12))
#   Downloading loralib-0.1.2-py3-none-any.whl.metadata (15 kB)
# Collecting fairscale (from -r /kaggle/working/OSEDiff/requirements.txt (line 13))
#   Downloading fairscale-0.4.13.tar.gz (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 20.3 MB/s eta 0:00:00
# done
#   Getting requirements to build wheel ... done
# done
# done
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (3.15.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /opt/conda/lib/python3.10/site-packages (from diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (0.26.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (0.4.5)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2)) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2)) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.28.1->-r /kaggle/working/OSEDiff/requirements.txt (line 3)) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.28.1->-r /kaggle/working/OSEDiff/requirements.txt (line 3))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.28.1->-r /kaggle/working/OSEDiff/requirements.txt (line 3)) (4.66.4)
# Collecting pyre-extensions==0.0.29 (from xformers==0.0.20->-r /kaggle/working/OSEDiff/requirements.txt (line 4))
#   Downloading pyre_extensions-0.0.29-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from open-clip-torch==2.20.0->-r /kaggle/working/OSEDiff/requirements.txt (line 6)) (0.19.0)
# Collecting ftfy (from open-clip-torch==2.20.0->-r /kaggle/working/OSEDiff/requirements.txt (line 6))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from open-clip-torch==2.20.0->-r /kaggle/working/OSEDiff/requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: protobuf<4 in /opt/conda/lib/python3.10/site-packages (from open-clip-torch==2.20.0->-r /kaggle/working/OSEDiff/requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: timm in /opt/conda/lib/python3.10/site-packages (from open-clip-torch==2.20.0->-r /kaggle/working/OSEDiff/requirements.txt (line 6)) (1.0.11)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from peft==0.9.0->-r /kaggle/working/OSEDiff/requirements.txt (line 7)) (5.9.3)
# Requirement already satisfied: accelerate>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.9.0->-r /kaggle/working/OSEDiff/requirements.txt (line 7)) (1.1.1)
# Collecting addict (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10))
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (1.0.0)
# Collecting lmdb (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10))
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (4.10.0.84)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (2.2.3)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (0.23.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (1.14.1)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (2.16.2)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (0.43.0)
# Requirement already satisfied: imgaug in /opt/conda/lib/python3.10/site-packages (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (0.4.0)
# Collecting openai-clip (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10))
#   Downloading openai-clip-1.0.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 64.1 MB/s eta 0:00:00
# done
# Collecting facexlib (from pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10))
#   Downloading facexlib-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2)) (70.0.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2)) (0.43.0)
# Requirement already satisfied: typing-inspect in /opt/conda/lib/python3.10/site-packages (from pyre-extensions==0.0.29->xformers==0.0.20->-r /kaggle/working/OSEDiff/requirements.txt (line 4)) (0.9.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading cmake-3.31.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting lit (from triton==2.0.0->torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2))
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Collecting tb-nightly (from basicsr->-r /kaggle/working/OSEDiff/requirements.txt (line 11))
#   Downloading tb_nightly-2.19.0a20241215-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.4->diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (2024.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.28.1->-r /kaggle/working/OSEDiff/requirements.txt (line 3)) (3.1.2)
# Collecting filterpy (from facexlib->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10))
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 14.7 MB/s eta 0:00:00
# done
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from facexlib->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (0.60.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from ftfy->open-clip-torch==2.20.0->-r /kaggle/working/OSEDiff/requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from imgaug->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from imgaug->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (3.7.5)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.10/site-packages (from imgaug->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (2.34.1)
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.10/site-packages (from imgaug->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (1.8.5.post1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (2024.5.22)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/conda/lib/python3.10/site-packages (from scikit-image->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (0.4)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2)) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.25.0->-r /kaggle/working/OSEDiff/requirements.txt (line 1)) (2024.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.0.1->-r /kaggle/working/OSEDiff/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->basicsr->-r /kaggle/working/OSEDiff/requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->basicsr->-r /kaggle/working/OSEDiff/requirements.txt (line 11)) (1.62.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->basicsr->-r /kaggle/working/OSEDiff/requirements.txt (line 11)) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->basicsr->-r /kaggle/working/OSEDiff/requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->basicsr->-r /kaggle/working/OSEDiff/requirements.txt (line 11)) (3.1.3)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imgaug->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (1.4.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->facexlib->pyiqa==0.1.10->-r /kaggle/working/OSEDiff/requirements.txt (line 10)) (0.43.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect->pyre-extensions==0.0.29->xformers==0.0.20->-r /kaggle/working/OSEDiff/requirements.txt (line 4)) (1.0.0)
# Downloading diffusers-0.25.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 71.4 MB/s eta 0:00:00
# Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.2 MB/s eta 0:00:00
# Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 3.6 MB/s eta 0:00:00
# Downloading xformers-0.0.20-cp310-cp310-manylinux2014_x86_64.whl (109.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 11.5 MB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.4 MB/s eta 0:00:00
# Downloading open_clip_torch-2.20.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 50.6 MB/s eta 0:00:00
# Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 14.7 MB/s eta 0:00:00
# Downloading Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 92.6 MB/s eta 0:00:00
# Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 42.5 MB/s eta 0:00:00
# Downloading pyiqa-0.1.10-py3-none-any.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 19.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 106.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 90.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 51.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 32.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 16.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 7.4 MB/s eta 0:00:00
# Downloading pyre_extensions-0.0.29-py3-none-any.whl (12 kB)
# Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 28.1 MB/s eta 0:00:00
# Downloading loralib-0.1.2-py3-none-any.whl (10 kB)
# Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.8 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading facexlib-0.3.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 4.8 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 25.8 MB/s eta 0:00:00
# Downloading tb_nightly-2.19.0a20241215-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 41.0 MB/s eta 0:00:00
# Downloading cmake-3.31.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 66.9 MB/s eta 0:00:00
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 8.5 MB/s eta 0:00:00
# Building wheels for collected packages: basicsr, fairscale, openai-clip, filterpy
# done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214819 sha256=eb4e50d218ce8836fb951e9b33557d8ebfc9fee773fa8bd74fb79bd477640bea
#   Stored in directory: /root/.cache/pip/wheels/38/83/99/2d8437cc652a01af27df5ff037a4075e95b52d67705c5f30ca
# done
#   Created wheel for fairscale: filename=fairscale-0.4.13-py3-none-any.whl size=332107 sha256=86704dd66470507c7033974c548cbbbf48ff5bc415e3b3363ddfc9d0c30cd2a1
#   Stored in directory: /root/.cache/pip/wheels/78/a4/c0/fb0a7ef03cff161611c3fa40c6cf898f76e58ec421b88e8cb3
# done
#   Created wheel for openai-clip: filename=openai_clip-1.0.1-py3-none-any.whl size=1368605 sha256=ae86e4624aee1c81bb1d2656054f44a5af41ddfd03deb4b34b6c47863ecccb05
#   Stored in directory: /root/.cache/pip/wheels/08/77/8e/8d2f862df6bf7fb4e2007062d2cbaeae49862ec7b56d041229
# done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=829c972d3aca2a8d36b6fd6ef742df9994f0bf1e731c7164ff6ef5badbe8bf36
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
# Successfully built basicsr fairscale openai-clip filterpy
# Installing collected packages: tokenizers, lmdb, lit, addict, PyYAML, Pillow, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, loralib, ftfy, einops, cmake, tb-nightly, pyre-extensions, openai-clip, nvidia-cusolver-cu11, nvidia-cudnn-cu11, transformers, filterpy, diffusers, triton, torch, facexlib, xformers, pyiqa, peft, open-clip-torch, fairscale, basicsr
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.3
#     Uninstalling transformers-4.46.3:
#       Successfully uninstalled transformers-4.46.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2024.9.0 requires dask==2024.9.0, but you have dask 2024.11.2 which is incompatible.
# jupyterlab 4.3.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# kaggle-environments 1.16.9 requires transformers>=4.33.1, but you have transformers 4.28.1 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.3 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.1 which is incompatible.
# rapids-dask-dependency 24.10.0a0 requires dask==2024.9.0, but you have dask 2024.11.2 which is incompatible.
# rapids-dask-dependency 24.10.0a0 requires dask-expr==1.1.14, but you have dask-expr 1.1.19 which is incompatible.
# ydata-profiling 4.12.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed Pillow-9.5.0 PyYAML-6.0 addict-2.4.0 basicsr-1.4.2 cmake-3.31.2 diffusers-0.25.0 einops-0.7.0 facexlib-0.3.0 fairscale-0.4.13 filterpy-1.4.5 ftfy-6.3.1 lit-18.1.8 lmdb-1.5.1 loralib-0.1.2 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 open-clip-torch-2.20.0 openai-clip-1.0.1 peft-0.9.0 pyiqa-0.1.10 pyre-extensions-0.0.29 tb-nightly-2.19.0a20241215 tokenizers-0.13.3 torch-2.0.1 transformers-4.28.1 triton-2.0.0 xformers-0.0.20
